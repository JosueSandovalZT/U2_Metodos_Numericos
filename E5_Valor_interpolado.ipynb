# %% [markdown]
# <a href="https://colab.research.google.com/github/JosueSandovalZT/U2_Metodos_Numericos/blob/main/E5_Valor_interpolado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicio 5: Valor interpolado

# %%
x0 = 1 # Primer punto en x
y0 = 2 # Valor correspondiente en y
x1 = 3 # Segundo punto en x
y1 = 6 # Valor correspondiente en y

x = 2 # Punto donde se desea interpolar

P = y0 + ((y1 - y0) / (x1 - x0)) * (x - x0) # Fórmula de interpolacion lineal

print("Valor interpolado:", P) # Mostrar resultado

# Grafica

import matplotlib.pyplot as plt

import numpy as np

x = np.linspace(0, 3, 100)

y = y0 + ((y1 - y0) / (x1 - x0)) * (x - x0)

plt.axhline(0)

plt.plot(x, y)

plt.title("Funcion f(x) = y0 + ((y1-y0)/(x1-x0))*(x-x0)")

plt.show()
# Out:
# Valor interpolado: 4.0
